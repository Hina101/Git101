# %%
#import library
import seaborn
#caanvas(Ballon board)
seaborn.set(style="whitegrid")
#
kashti=seaborn.load_dataset("titanic")
seaborn.boxplot(x="class",
                y="fare",
                data=kashti)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='class', ylabel='fare'>

# %%
#import library
import seaborn
#caanvas(Ballon board)
seaborn.set(style="whitegrid")
#
kashti=seaborn.load_dataset("titanic")
seaborn.boxplot(x="class",y="fare",data=kashti)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='class', ylabel='fare'>

# %%
#import library
import seaborn as sns
#caanvas(Ballon board)
sns.set(style="whitegrid")
#
kashti=sns.load_dataset("titanic")
sns.boxplot(x="class",
                y="fare",
                data=kashti)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='class', ylabel='fare'>

# %%
#import library
import seaborn
#caanvas(Ballon board)
seaborn.set(style="whitegrid")
#
tip=seaborn.load_dataset("tips")
tip
seaborn.boxplot(x="day", y="tip",data=tip)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='tip'>

# %%
#Saturation
#import library
import seaborn
#caanvas(Ballon board)
seaborn.set(style="whitegrid")
#
tip=seaborn.load_dataset("tips")
tip
seaborn.boxplot(x="day", y="tip",data=tip,saturation=1)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
tip=sns.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#tips shows all catagorical varibles but tips.describe shows numerical variables
#numeric variables are mostly drwan on y axis and catagorical drwan on x axis
#catagorical drwan on x axis or in hue

# %%
import seaborn as sns
#use to set style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip=sns.load_dataset("tips")
sns.boxplot(x=tip['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
import seaborn as sns
#use to set style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip=sns.load_dataset("tips")
sns.boxplot(y=tip['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
import seaborn as sns
#use to set style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip=sns.load_dataset("tips")
sns.boxplot(x=tip['size'])
# Out:
# <Axes: xlabel='size'>

# %%
import seaborn as sns
#use to set style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip=sns.load_dataset("tips")
sns.boxplot(x='tip',y='day',data=tip)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
#use to set style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip=sns.load_dataset("tips")
sns.boxplot(x='tip',y='day',hue='smoker', data=tip)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
#use to set style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip=sns.load_dataset("tips")
sns.boxplot(x='tip',y='day',hue='smoker',data=tip,palette='Set2', dodge=True )
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
#use to set style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip=sns.load_dataset("tips")
sns.boxplot(x='tip',y='day',hue='smoker',data=tip,palette='Set2', dodge=False)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
#use to set style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip=sns.load_dataset("tips")
sns.boxplot(x='tip',y='day',hue='smoker',data=tip,palette='Set2', dodge=True,orient="h")
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='tip', ylabel='day'>

# %%
#Saturation
#import library
import seaborn
#caanvas(Ballon board)
seaborn.set(style="whitegrid")
#
tip=seaborn.load_dataset("tips")
tip
seaborn.boxplot(x="day", y="tip",data=tip,saturation=1)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='tip'>

# %%
#import library
import seaborn
#caanvas(Ballon board)
seaborn.set(style="whitegrid")
#
tip=seaborn.load_dataset("tips")
tip
seaborn.boxplot(x="day", y="tip",data=tip,color='red')
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='tip'>

# %%
#import library
import seaborn
#caanvas(Ballon board)
seaborn.set(style="whitegrid")
#
tip=seaborn.load_dataset("tips")
tip
seaborn.boxplot(x="day", y="tip",data=tip,color='#a83268')
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='tip'>

# %%
#whenever you use other color names like smoker than u will not add directly to color it will not work u have to add in hue
#How to give color to hue's yes or no
#how to manage individual colors for each hue color

# %%
#import library
import seaborn
#caanvas(Ballon board)
seaborn.set(style="whitegrid")
#
tip=seaborn.load_dataset("tips")
tip
palette={'Yes':'Yellow','No':"Red"}
seaborn.boxplot(x="day", y="total_bill",hue="smoker",data=tip,palette=palette)
# Out:
# C:\Users\hinar\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>
